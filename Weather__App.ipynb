# %% [markdown]
# <a href="https://colab.research.google.com/github/GuptaMuskan382/OIBSIP-/blob/main/Weather__App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

print("=" * 40)
print("        WEATHER APP")
print("=" * 40)

city = input("Enter city name: ")

url = f"https://wttr.in/{city}?format=j1"

try:
    response = requests.get(url)
    data = response.json()

    current = data["current_condition"][0]

    print("\nWeather Report")
    print("-" * 40)
    print("City:", city.title())
    print("Temperature:", current["temp_C"], "°C")
    print("Feels Like:", current["FeelsLikeC"], "°C")
    print("Humidity:", current["humidity"], "%")
    print("Wind Speed:", current["windspeedKmph"], "km/h")
    print("Condition:", current["weatherDesc"][0]["value"])
    print("-" * 40)

except Exception as e:
    print("Error:", e)
# Out:
# ...
#         WEATHER APP
# ...
# Enter city name: Delhi
#
# Weather Report
# ----------------------------------------
# City: Delhi
# Temperature: 29 °C
# Feels Like: 35 °C
# Humidity: 79 %
# Wind Speed: 21 km/h
# Condition: Mist
# ----------------------------------------
